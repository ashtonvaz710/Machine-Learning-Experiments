# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import operator

# %%
def l2_logistic_regression(train_data, test_data, train_labels, test_labels):
    
    # Train model
    model = LogisticRegression(penalty='l2', random_state=42)
    model.fit(train_data, train_labels)

    # Test model
    y_train_pred = model.predict(train_data)
    y_test_pred = model.predict(test_data)

    # Evaluate model
    print('\nLogistic Regression - \nTrain Accuracy: ', round(np.sum(y_train_pred == train_labels) / train_data.shape[0], 4))
    print('Test Accuracy: ', round(np.sum(y_test_pred == test_labels) / test_data.shape[0], 4))

# %%
def decision_tree_classifier(train_data, test_data, train_labels, test_labels):

    # Train model
    model = DecisionTreeClassifier(random_state=42)
    model.fit(train_data, train_labels)
    
    # Test model
    y_train_pred = model.predict(train_data)
    y_test_pred = model.predict(test_data)

    # Evaluate model
    print('\nDecision Tree - \nTrain Accuracy: ', round(np.sum(y_train_pred == train_labels) / train_data.shape[0], 4))
    print('Test Accuracy: ', round(np.sum(y_test_pred == test_labels) / test_data.shape[0], 4))

# %%
# Fetch data
ng_train = fetch_20newsgroups(subset='train')
ng_test = fetch_20newsgroups(subset='test')

# Training and testing data
X_train = ng_train.data
X_test = ng_test.data

# Set of label names for training and testing data
# ng_train.target_names
# ng_test.target_names

# Training and testing labels, where each label is associated with a number corresponding to the index in target_names
# ng_train.target
# ng_test.target

# Training and testing labels
y_train = []
y_test = []

for i in range(len(X_train)):
    y_train.append(ng_train.target_names[ng_train.target[i]])
for i in range(len(X_test)):
    y_test.append(ng_test.target_names[ng_test.target[i]])

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 18846
# 18846
# 11314
# 7532
# 11314
# 7532

# %%
# Take the max coefficient

tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(X_train)
vect_X_train = tfidf.transform(X_train)
vect_X_test = tfidf.transform(X_test)

print(vect_X_train.shape)
print(vect_X_test.shape)

l2_logistic_regression(vect_X_train, vect_X_test, y_train, y_test)
decision_tree_classifier(vect_X_train, vect_X_test, y_train, y_test)
print('---------------')

K = 200
for C in [0.1, 0.5, 1.0, 10.0]:
    print('C=' + str(C))
    model = LogisticRegression(penalty='l1', C=C, random_state=42)

    model.fit(vect_X_train, y_train)
    importances = model.coef_      # Scores of each feature

    # Store top k features
    features = tfidf.get_feature_names()
    new_features_weights = {}
    for i in range(len(importances)):
        indices = np.argsort(importances[i])[::-1]

        for f in range(K):
            if features[indices[f]] in new_features_weights:
                new_features_weights[features[indices[f]]] = max(new_features_weights[features[indices[f]]], importances[i][indices[f]])
            else:
                new_features_weights.setdefault(features[indices[f]], importances[i][indices[f]])
    
    new_features_weights = sorted(new_features_weights.items(), key=operator.itemgetter(1), reverse=True)[:K]
    
    new_features = []
    for k,v in new_features_weights:
        new_features.append(k)
    print(new_features)
    
    # Convert train and test data to vectors based on k features
    tfidf_train = TfidfVectorizer(stop_words='english', vocabulary=new_features)
    new_vect_X_train = tfidf_train.fit_transform(X_train)

    tfidf_test = TfidfVectorizer(stop_words='english', vocabulary=new_features)
    new_vect_X_test = tfidf_test.fit_transform(X_test)

    # Perform classification on data with k features
    l2_logistic_regression(new_vect_X_train, new_vect_X_test, y_train, y_test)
    decision_tree_classifier(new_vect_X_train, new_vect_X_test, y_train, y_test)
    print('---------------')
# Out:
# (11314, 129796)
# (7532, 129796)
#
# Logistic Regression -
# Train Accuracy:  0.9746
# Test Accuracy:  0.8302
#
# Decision Tree -
# Train Accuracy:  0.9999
# Test Accuracy:  0.5645
# ---------------
# C=0.1
# ['sale', 'dod', 'windows', 'space', 'car', 'gun', 'clipper', 'bike', 'baseball', 'hockey', 'graphics', 'israel', 'mac', 'key', 'israeli', 'keith', 'god', 'window', 'encryption', 'apple', 'turkish', 'team', 'cars', 'pitt', 'motif', 'christians', 'game', 'cramer', 'msg', 'church', 'drive', 'server', 'year', 'fbi', 'sandvik', 'nhl', 'geb', 'bus', 'armenian', 'card', 'henry', 'moon', 'armenians', 'scsi', 'nasa', 'jesus', 'atheism', 'jews', 'batf', 'ca', 'mit', 'guns', 'livesey', 'rutgers', 'stratus', 'atheists', 'ide', 'digex', 'creators', 'creator', 'creativity', 'creatively', 'creations', 'creative', 'creationists', 'creationist', 'creationism', 'creation', 'creatio', 'creats', 'creatures', 'creature', 'createwindow', 'credence', 'credential', 'credentials', 'credibility', 'credible', 'credibly', 'credit', 'creditable', 'credited', 'creditors', 'credits', 'credo', 'creating', 'ýé', 'credulous', 'crcmap', 'crazies', 'craziest', 'craziness', 'crazy', 'crb', 'crb7q', 'crc', 'crchh403', 'crchh410', 'crchh435', 'crchh574', 'crchh67', 'crchh7a9', 'crcnis1', 'creates', 'crd', 'crdgw1', 'crdnns', 'crdx', 'cre', 'cream', 'creams', 'crease', 'create', 'create_8bit_window_on_truecolour_display', 'create_form', 'create_form_widget', 'created', 'credulity', 'creed', 'credulously', 'crichton', 'crews', 'crg1', 'crg8', 'crgruen', 'crh', 'crhai', 'crhc', 'cri', 'crib', 'cribs', 'crica', 'crichar', 'crichmon', 'crick', 'crazed', 'cricket', 'cried', 'cries', 'criiterion', 'crim', 'crime', 'crimea', 'crimean', 'crimes', 'crimestrike', 'crimial', 'criminal', 'criminality', 'crew', 'cretins', 'cretinous', 'crete', 'creeds', 'creegan', 'creek', 'creel', 'creep', 'creeping', 'creeps', 'creepy', 'creighton', 'crematorium', 'creme', 'crenellated', 'creol', 'creolc51grd', 'creosote', 'creosoted', 'crepancy', 'creps', 'crept', 'cres', 'crescendo', 'crescent', 'crescenta', 'crescentville', 'crest', 'cretaceous', 'cretainly', 'crazier', 'crays', 'craze', 'crackpot', 'crabbe', 'crabby', 'crabtree', 'crack', 'crackable', 'crackdown', 'crackdowns', 'cracked', 'cracker', 'crackers', 'cracking', 'crackle', 'crackling', 'crackpots', 'cra', 'cracks']
#
# Logistic Regression -
# Train Accuracy:  0.5898
# Test Accuracy:  0.5239
#
# Decision Tree -
# Train Accuracy:  0.6845
# Test Accuracy:  0.4935
# ---------------
# C=0.5
# ['nhl', 'encryption', 'hockey', 'bike', 'clipper', 'israeli', 'dod', 'sale', 'geb', 'gun', 'atheism', 'baseball', 'israel', 'turkish', 'cramer', 'guns', 'armenian', 'motif', 'moon', 'armenians', 'livesey', 'space', 'atheists', 'batf', 'windows', 'car', 'cars', 'rutgers', 'henry', 'christians', 'msg', 'key', 'jews', 'digex', 'apple', 'fbi', 'crabtree', 'graphics', 'mac', 'church', 'sandvik', 'stratus', 'window', 'server', 'keith', 'team', 'god', 'ide', 'game', 'creationist', 'nasa', 'bus', 'crchh410', 'mit', 'jesus', 'scsi', 'credulous', 'creegan', 'creation', 'crimes', 'criminal', 'year', 'crazy', 'card', 'ca', 'drive', 'creations', 'pitt', 'crime', 'cries', 'creationism', 'crack', 'cri', 'ýé', 'creed', 'crew', 'create', 'cracking', 'creating', 'crchh7a9', 'credit', 'created', 'creates', 'creative', 'crackdowns', 'crd', 'creams', 'credible', 'credibility', 'cried', 'creature', 'cracked', 'cream', 'creditors', 'craziest', 'credibly', 'credits', 'credo', 'creditable', 'crcmap', 'crazies', 'credited', 'cracks', 'craziness', 'crcnis1', 'cre', 'crdx', 'crdnns', 'crdgw1', 'credential', 'crchh67', 'cra', 'crchh435', 'crchh403', 'crc', 'crb7q', 'crb', 'credentials', 'creatures', 'credence', 'createwindow', 'creationists', 'crease', 'creats', 'creatio', 'creatively', 'creativity', 'creator', 'creators', 'crchh574', 'creosoted', 'crescentville', 'crescenta', 'crescent', 'crescendo', 'cres', 'crept', 'creps', 'create_8bit_window_on_truecolour_display', 'creosote', 'creep', 'creolc51grd', 'creol', 'crenellated', 'creme', 'crematorium', 'creighton', 'creepy', 'creeps', 'crest', 'cretaceous', 'cretainly', 'crazier', 'crackpots', 'crackling', 'crackle', 'crackers', 'cracker', 'crackdown', 'crackable', 'crabby', 'crabbe', 'crackpot', 'craze', 'crays', 'creeping', 'crepancy', 'creel', 'create_form_widget', 'crichmon', 'crichar', 'crica', 'cribs', 'crib', 'crhc', 'creek', 'credulity', 'cricket', 'crhai', 'crh', 'crgruen', 'crg8', 'crg1', 'credulously', 'crews', 'crick', 'crazed', 'crimean', 'creeds', 'crete', 'cretinous', 'cretins', 'criminality', 'crimial', 'crimestrike', 'crimea', 'crim', 'create_form', 'criiterion', 'crichton']
#
# Logistic Regression -
# Train Accuracy:  0.5898
# Test Accuracy:  0.5239
#
# Decision Tree -
# Train Accuracy:  0.6845
# Test Accuracy:  0.4943
# ---------------
# C=1.0
# ['nhl', 'encryption', 'hockey', 'bike', 'clipper', 'israeli', 'dod', 'geb', 'armenian', 'sale', 'atheism', 'gun', 'cramer', 'baseball', 'armenians', 'guns', 'turkish', 'motif', 'israel', 'moon', 'crabtree', 'livesey', 'atheists', 'batf', 'space', 'car', 'windows', 'cars', 'rutgers', 'henry', 'creationist', 'msg', 'christians', 'jews', 'sandvik', 'key', 'digex', 'fbi', 'apple', 'graphics', 'stratus', 'mac', 'church', 'creams', 'crchh410', 'window', 'server', 'credulous', 'keith', 'ide', 'creegan', 'god', 'ýé', 'team', 'cries', 'game', 'nasa', 'creations', 'bus', 'crchh574', 'cried', 'creationism', 'jesus', 'mit', 'crchh7a9', 'crackdowns', 'scsi', 'criminal', 'creed', 'creation', 'crimes', 'crazy', 'cri', 'crd', 'cracking', 'creditors', 'crack', 'pitt', 'crichmon', 'crhc', 'year', 'crchh67', 'crime', 'card', 'ca', 'drive', 'creativity', 'crew', 'credibility', 'cracked', 'crease', 'creating', 'creeping', 'creditable', 'credible', 'creature', 'credit', 'creates', 'create', 'cream', 'created', 'creative', 'creator', 'creeds', 'crh', 'crg8', 'crc', 'credits', 'credited', 'crazies', 'criiterion', 'credo', 'credibly', 'craziness', 'craziest', 'cracks', 'cre', 'crcnis1', 'crchh403', 'crdx', 'creatures', 'crdnns', 'credentials', 'crdgw1', 'credential', 'crb', 'cra', 'crchh435', 'crb7q', 'crichton', 'createwindow', 'credence', 'crcmap', 'creationists', 'crichar', 'cricket', 'creek', 'crib', 'cribs', 'crica', 'create_form_widget', 'creel', 'crepancy', 'crays', 'craze', 'crackpot', 'crhai', 'crgruen', 'crabby', 'cretinous', 'create_form', 'crim', 'crimea', 'crimestrike', 'crimial', 'criminality', 'cretins', 'crete', 'crimean', 'crazed', 'crick', 'crews', 'credulously', 'crg1', 'crabbe', 'credulity', 'crackable', 'crackdown', 'creep', 'creosote', 'create_8bit_window_on_truecolour_display', 'creps', 'crept', 'cres', 'crescendo', 'crescent', 'crescentville', 'creol', 'creosoted', 'creators', 'creatively', 'creatio', 'creats', 'creolc51grd', 'crescenta', 'crenellated', 'creepy', 'cracker', 'crackers', 'crackle', 'crackling', 'crackpots', 'creme', 'crazier', 'cretainly', 'cretaceous', 'crest', 'creeps', 'creighton', 'crematorium']
#
# Logistic Regression -
# Train Accuracy:  0.5898
# Test Accuracy:  0.5239
#
# Decision Tree -
# Train Accuracy:  0.6845
# Test Accuracy:  0.4959
# ---------------
# C=10.0
# ['creatively', 'nhl', 'crick', 'crazier', 'encryption', 'crabtree', 'creams', 'credo', 'hockey', 'armenian', 'cre', 'creatio', 'armenians', 'crchh67', 'israeli', 'creosoted', 'geb', 'bike', 'clipper', 'creationist', 'dod', 'crchh7a9', 'ýé', 'atheism', 'crackdowns', 'baseball', 'cramer', 'credential', 'credulous', 'creegan', 'crichmon', 'gun', 'sale', 'guns', 'crchh574', 'cretainly', 'motif', 'moon', 'turkish', 'crg8', 'creditors', 'crhc', 'atheists', 'israel', 'craze', 'cried', 'crescendo', 'crg1', 'livesey', 'crept', 'crimestrike', 'crichton', 'batf', 'crenellated', 'crimial', 'createwindow', 'cracker', 'cries', 'creepy', 'msg', 'sandvik', 'creighton', 'crcnis1', 'crete', 'craziness', 'crescenta', 'car', 'crdnns', 'cars', 'space', 'credulously', 'crdx', 'windows', 'creativity', 'crackling', 'crchh410', 'rutgers', 'crhai', 'henry', 'creatures', 'create_form_widget', 'jews', 'christians', 'fbi', 'credibly', 'digex', 'apple', 'crabby', 'crh', 'crease', 'key', 'crchh403', 'graphics', 'creations', 'cres', 'creationism', 'stratus', 'mac', 'church', 'crichar', 'criiterion', 'crazed', 'server', 'crackle', 'credence', 'window', 'ide', 'creps', 'crews', 'keith', 'crescent', 'creats', 'creme', 'creeds', 'crd', 'creditable', 'god', 'crb7q', 'cracked', 'team', 'creed', 'creeping', 'credentials', 'bus', 'nasa', 'credits', 'mit', 'game', 'jesus', 'criminal', 'cracking', 'crc', 'scsi', 'crdgw1', 'credibility', 'crack', 'creationists', 'cri', 'crimes', 'creation', 'crazies', 'cretinous', 'creek', 'cracks', 'creol', 'creature', 'cream', 'crazy', 'crime', 'crew', 'credited', 'credible', 'creator', 'pitt', 'year', 'card', 'drive', 'crib', 'creating', 'creates', 'ca', 'crackers', 'creolc51grd', 'credit', 'create', 'creators', 'created', 'creative', 'crescentville', 'cretins', 'crb', 'crabbe', 'craziest', 'cra', 'crchh435', 'crematorium', 'creep', 'create_8bit_window_on_truecolour_display', 'creosote', 'crackdown', 'crackable', 'cretaceous', 'credulity', 'crackpots', 'create_form', 'cribs', 'creel', 'crepancy', 'crays', 'crackpot', 'crgruen', 'crim', 'crimea', 'criminality', 'creeps', 'cricket', 'crcmap', 'crimean', 'crest', 'crica']
# Logistic Regression -
# Train Accuracy:  0.5898
# Test Accuracy:  0.5239
#
# Decision Tree -
# Train Accuracy:  0.6845
# Test Accuracy:  0.4946
# ---------------

# %%
# Sum up coefficients

tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(X_train)
vect_X_train = tfidf.transform(X_train)
vect_X_test = tfidf.transform(X_test)

print(vect_X_train.shape)
print(vect_X_test.shape)

l2_logistic_regression(vect_X_train, vect_X_test, y_train, y_test)
decision_tree_classifier(vect_X_train, vect_X_test, y_train, y_test)
print('---------------')

K = 200
for C in [0.1, 0.5, 1.0, 10.0]:
    print('C=' + str(C))
    model = LogisticRegression(penalty='l1', C=C, random_state=42)

    model.fit(vect_X_train, y_train)
    importances = model.coef_      # Scores of each feature

    # Store top k features
    features = vectorizer_newsgroups_train.get_feature_names()
    new_features_weights = {}
    for i in range(len(importances)):
        indices = np.argsort(importances[i])[::-1]

        for f in range(K):
            if features[indices[f]] in new_features_weights:
                new_features_weights[features[indices[f]]] += importances[i][indices[f]]
            else:
                new_features_weights.setdefault(features[indices[f]], importances[i][indices[f]])
    
    new_features_weights = sorted(new_features_weights.items(), key=operator.itemgetter(1), reverse=True)[:K]
    
    new_features = []
    for k,v in new_features_weights:
        new_features.append(k)
    print(new_features)
    
    # Convert train and test data to vectors based on k features
    tfidf_train = TfidfVectorizer(stop_words='english', vocabulary=new_features)
    new_vect_X_train = tfidf_train.fit_transform(X_train)

    tfidf_test = TfidfVectorizer(stop_words='english', vocabulary=new_features)
    new_vect_X_test = tfidf_test.fit_transform(X_test)

    # Perform classification on data with k features
    l2_logistic_regression(new_vect_X_train, new_vect_X_test, y_train, y_test)
    decision_tree_classifier(new_vect_X_train, new_vect_X_test, y_train, y_test)
    print('---------------')
# Out:
# (11314, 129796)
# (7532, 129796)
#
# Logistic Regression -
# Train Accuracy:  0.9746
# Test Accuracy:  0.8302
#
# Decision Tree -
# Train Accuracy:  0.9999
# Test Accuracy:  0.5645
# ---------------
# C=0.1
# ['sale', 'dod', 'windows', 'space', 'car', 'gun', 'clipper', 'bike', 'god', 'baseball', 'hockey', 'graphics', 'israel', 'mac', 'key', 'israeli', 'team', 'keith', 'window', 'encryption', 'apple', 'turkish', 'cars', 'pitt', 'motif', 'christians', 'game', 'cramer', 'msg', 'church', 'drive', 'server', 'year', 'fbi', 'sandvik', 'jesus', 'nhl', 'geb', 'bus', 'armenian', 'card', 'henry', 'moon', 'armenians', 'scsi', 'nasa', 'atheism', 'jews', 'batf', 'ca', 'mit', 'guns', 'livesey', 'rutgers', 'stratus', 'atheists', 'ide', 'digex', 'creators', 'creator', 'creativity', 'creatively', 'creations', 'creative', 'creationists', 'creationist', 'creationism', 'creation', 'creatio', 'creats', 'creatures', 'creature', 'createwindow', 'credence', 'credential', 'credentials', 'credibility', 'credible', 'credibly', 'credit', 'creditable', 'credited', 'creditors', 'credits', 'credo', 'creating', 'ýé', 'credulous', 'crcmap', 'crazies', 'craziest', 'craziness', 'crazy', 'crb', 'crb7q', 'crc', 'crchh403', 'crchh410', 'crchh435', 'crchh574', 'crchh67', 'crchh7a9', 'crcnis1', 'creates', 'crd', 'crdgw1', 'crdnns', 'crdx', 'cre', 'cream', 'creams', 'crease', 'create', 'create_8bit_window_on_truecolour_display', 'create_form', 'create_form_widget', 'created', 'credulity', 'creed', 'credulously', 'crichton', 'crews', 'crg1', 'crg8', 'crgruen', 'crh', 'crhai', 'crhc', 'cri', 'crib', 'cribs', 'crica', 'crichar', 'crichmon', 'crick', 'crazed', 'cricket', 'cried', 'cries', 'criiterion', 'crim', 'crime', 'crimea', 'crimean', 'crimes', 'crimestrike', 'crimial', 'criminal', 'criminality', 'crew', 'cretins', 'cretinous', 'crete', 'creeds', 'creegan', 'creek', 'creel', 'creep', 'creeping', 'creeps', 'creepy', 'creighton', 'crematorium', 'creme', 'crenellated', 'creol', 'creolc51grd', 'creosote', 'creosoted', 'crepancy', 'creps', 'crept', 'cres', 'crescendo', 'crescent', 'crescenta', 'crescentville', 'crest', 'cretaceous', 'cretainly', 'crazier', 'crays', 'craze', 'crackpot', 'crabbe', 'crabby', 'crabtree', 'crack', 'crackable', 'crackdown', 'crackdowns', 'cracked', 'cracker', 'crackers', 'cracking', 'crackle', 'crackling', 'crackpots', 'cra', 'cracks']
#
# Logistic Regression -
# Train Accuracy:  0.5898
# Test Accuracy:  0.5239
#
# Decision Tree -
# Train Accuracy:  0.6845
# Test Accuracy:  0.4976
# ---------------
# C=0.5
# ['crazy', 'ca', 'criminal', 'stratus', 'atheism', 'livesey', 'crabtree', 'armenians', 'sandvik', 'crack', 'armenian', 'creating', 'crimes', 'creationist', 'batf', 'crchh410', 'cramer', 'msg', 'credulous', 'created', 'create', 'henry', 'creegan', 'creation', 'cri', 'credit', 'crime', 'creations', 'cries', 'creationism', 'crew', 'digex', 'ýé', 'creed', 'geb', 'atheists', 'creates', 'cracking', 'creative', 'crchh7a9', 'moon', 'nhl', 'ide', 'bus', 'crackdowns', 'crd', 'creams', 'turkish', 'credible', 'credibility', 'motif', 'cried', 'creature', 'cracked', 'jews', 'cream', 'mit', 'server', 'crcmap', 'credo', 'cracks', 'credits', 'creditors', 'credited', 'creditable', 'credibly', 'crazies', 'crb', 'craziest', 'crcnis1', 'cre', 'crdx', 'crdnns', 'crdgw1', 'craziness', 'crchh67', 'cra', 'crchh435', 'crchh403', 'crc', 'crb7q', 'credential', 'credentials', 'creatures', 'credence', 'createwindow', 'creationists', 'crease', 'creats', 'creatio', 'creatively', 'creativity', 'creator', 'creators', 'crchh574', 'creosoted', 'crescentville', 'crescenta', 'crescent', 'crescendo', 'cres', 'crept', 'creps', 'create_8bit_window_on_truecolour_display', 'creosote', 'creep', 'creolc51grd', 'creol', 'crenellated', 'creme', 'crematorium', 'creighton', 'creepy', 'creeps', 'crest', 'cretaceous', 'cretainly', 'crazier', 'crackpots', 'crackling', 'crackle', 'crackers', 'cracker', 'crackdown', 'crackable', 'crabby', 'crabbe', 'crackpot', 'craze', 'crays', 'creeping', 'crepancy', 'creel', 'cricket', 'crichmon', 'create_form_widget', 'crichar', 'crica', 'cribs', 'crib', 'crhc', 'creek', 'credulity', 'crhai', 'crh', 'crgruen', 'crg8', 'crg1', 'credulously', 'crews', 'crichton', 'crick', 'crazed', 'creeds', 'cretins', 'criminality', 'crimial', 'cretinous', 'crimestrike', 'crete', 'crimean', 'crimea', 'crim', 'create_form', 'criiterion', 'scsi', 'year', 'nasa', 'keith', 'fbi', 'church', 'guns', 'israeli', 'pitt', 'drive', 'cars', 'encryption', 'christians', 'window', 'hockey', 'key', 'space', 'apple', 'card', 'game', 'graphics', 'mac', 'jesus', 'israel', 'baseball', 'rutgers', 'gun', 'bike', 'clipper', 'dod', 'car', 'team', 'god', 'sale', 'windows']
#
# Logistic Regression -
# Train Accuracy:  0.5898
# Test Accuracy:  0.5239
#
# Decision Tree -
# Train Accuracy:  0.6845
# Test Accuracy:  0.4963
# ---------------
# C=1.0
# ['crabtree', 'crazy', 'criminal', 'crew', 'crd', 'creationist', 'credibility', 'creams', 'crchh410', 'creed', 'credulous', 'credit', 'creating', 'crack', 'cri', 'ca', 'creegan', 'ýé', 'cries', 'crimes', 'creation', 'creates', 'cracking', 'creations', 'crchh574', 'cried', 'creationism', 'creature', 'crchh7a9', 'crackdowns', 'cracked', 'creditors', 'crease', 'cream', 'crichmon', 'crhc', 'crchh67', 'creativity', 'creative', 'creator', 'creeping', 'creditable', 'credible', 'creeds', 'stratus', 'crh', 'crg8', 'crc', 'crcnis1', 'crchh435', 'credibly', 'crazies', 'credentials', 'credential', 'crb7q', 'crchh403', 'cra', 'crb', 'craziness', 'crdgw1', 'crdnns', 'creatures', 'craziest', 'cre', 'crdx', 'creationists', 'credence', 'creps', 'crept', 'cres', 'crescent', 'crescenta', 'crescentville', 'creosoted', 'creators', 'createwindow', 'creatively', 'creatio', 'creats', 'credited', 'credits', 'cracks', 'credo', 'crcmap', 'creosote', 'create_8bit_window_on_truecolour_display', 'crescendo', 'creep', 'crick', 'cribs', 'crib', 'creek', 'credulity', 'crhai', 'crgruen', 'crg1', 'credulously', 'crews', 'crichton', 'crazed', 'crichar', 'creolc51grd', 'criminality', 'crimial', 'cretinous', 'crimestrike', 'crete', 'crimean', 'crimea', 'crim', 'create_form', 'criiterion', 'crica', 'cretins', 'create_form_widget', 'crackers', 'crenellated', 'creol', 'creme', 'crematorium', 'creighton', 'creepy', 'creeps', 'crest', 'cretaceous', 'cretainly', 'crazier', 'crackling', 'crackle', 'crackpots', 'craze', 'crabby', 'crepancy', 'crays', 'cricket', 'crackpot', 'crabbe', 'crackable', 'crackdown', 'cracker', 'creel', 'sandvik', 'created', 'armenians', 'armenian', 'atheism', 'create', 'livesey', 'year', 'henry', 'msg', 'digex', 'batf', 'mit', 'bus', 'server', 'crime', 'geb', 'cramer', 'nasa', 'ide', 'keith', 'moon', 'drive', 'jews', 'key', 'scsi', 'church', 'turkish', 'motif', 'space', 'nhl', 'atheists', 'fbi', 'guns', 'window', 'cars', 'pitt', 'game', 'apple', 'mac', 'card', 'christians', 'israeli', 'graphics', 'encryption', 'hockey', 'gun', 'israel', 'jesus', 'god', 'rutgers', 'baseball', 'car', 'team', 'bike', 'dod', 'clipper', 'sale', 'windows']
#
# Logistic Regression -
# Train Accuracy:  0.5898
# Test Accuracy:  0.5239
#
# Decision Tree -
# Train Accuracy:  0.6845
# Test Accuracy:  0.4954
# ---------------
# C=10.0
# ['creatively', 'crick', 'cre', 'credo', 'creams', 'creatio', 'creatures', 'crdnns', 'credential', 'crete', 'craze', 'crept', 'creosoted', 'cretainly', 'crhai', 'crichton', 'crescendo', 'crg1', 'crimial', 'creepy', 'credits', 'crackdowns', 'crichmon', 'creditors', 'creationists', 'crackling', 'craziness', 'create_form_widget', 'crhc', 'crb7q', 'crackle', 'crchh403', 'cracker', 'crchh67', 'createwindow', 'credibly', 'creeds', 'credence', 'crichar', 'crescenta', 'crdx', 'crenellated', 'creditable', 'creps', 'cres', 'creme', 'crchh574', 'crabby', 'crh', 'credulously', 'creek', 'creep', 'crchh7a9', 'cretinous', 'criiterion', 'crimestrike', 'creolc51grd', 'crazed', 'crc', 'crews', 'crescent', 'creativity', 'crib', 'creats', 'creol', 'crazier', 'crackers', 'ýé', 'ca', 'creators', 'crdgw1', 'creationist', 'crazies', 'credentials', 'cretins', 'creed', 'crescentville', 'creeping', 'cracks', 'credibility', 'crcnis1', 'crabbe', 'cried', 'crg8', 'crb', 'crgruen', 'crica', 'criminality', 'crimean', 'crimea', 'crim', 'create_form', 'crcmap', 'craziest', 'creosote', 'create_8bit_window_on_truecolour_display', 'cribs', 'crchh435', 'crematorium', 'creeps', 'crest', 'cretaceous', 'crackpots', 'crepancy', 'crays', 'cricket', 'crackpot', 'crackable', 'crackdown', 'creel', 'cra', 'crabtree', 'creighton', 'credulity', 'creegan', 'cries', 'credit', 'credited', 'creationism', 'creations', 'credible', 'credulous', 'crease', 'crd', 'creator', 'crchh410', 'year', 'crazy', 'cream', 'cracking', 'creature', 'created', 'cracked', 'creation', 'key', 'cri', 'mit', 'creating', 'creative', 'create', 'nasa', 'creates', 'space', 'drive', 'stratus', 'server', 'crew', 'crack', 'keith', 'criminal', 'crimes', 'digex', 'god', 'game', 'armenians', 'bus', 'armenian', 'apple', 'sandvik', 'henry', 'church', 'mac', 'window', 'car', 'graphics', 'crime', 'card', 'msg', 'jews', 'gun', 'livesey', 'batf', 'geb', 'cars', 'turkish', 'scsi', 'atheism', 'team', 'cramer', 'moon', 'guns', 'fbi', 'israel', 'ide', 'christians', 'pitt', 'motif', 'baseball', 'sale', 'dod', 'jesus', 'israeli', 'windows', 'rutgers', 'nhl', 'hockey', 'encryption', 'bike', 'clipper', 'atheists']
# Logistic Regression -
# Train Accuracy:  0.5898
# Test Accuracy:  0.5239
#
# Decision Tree -
# Train Accuracy:  0.6845
# Test Accuracy:  0.4936
# ---------------
