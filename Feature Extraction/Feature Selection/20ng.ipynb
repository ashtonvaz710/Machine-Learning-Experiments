# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import matplotlib.pyplot as plt

# %%
def l2_logistic_regression(train_data, test_data, train_labels, test_labels):
    
    # Train model
    model = LogisticRegression(penalty='l2', random_state=42)
    model.fit(train_data, train_labels)    
    
    # Extract top features from model
    importances = model.coef_
    
    for i in range(len(importances)):
        indices = np.argsort(importances[i])[::-1]

        print('\nFeature ranking for label ' + str(i) + ':') if len(importances) > 1 else print('Feature ranking:')
        for f in range(30):
            print('%d. Feature %d (%f)' % (f + 1, indices[f], importances[i][indices[f]]))

    # Test model
    y_train_pred = model.predict(train_data)
    y_test_pred = model.predict(test_data)

    # Evaluate model
    print('\nLogistic Regression - \nTrain Accuracy: ', round(np.sum(y_train_pred == train_labels) / train_data.shape[0], 4))
    print('Test Accuracy: ', round(np.sum(y_test_pred == test_labels) / test_data.shape[0], 4))

# %%
def decision_tree_classifier(train_data, test_data, train_labels, test_labels):

    # Train model
    for model in [
        DecisionTreeClassifier(random_state=42), 
        DecisionTreeClassifier(random_state=42, max_depth=10), 
        DecisionTreeClassifier(random_state=42, min_samples_leaf=2), 
        DecisionTreeClassifier(random_state=42, min_samples_split=3)
    ]:
        
        model.fit(train_data, train_labels)

        # Extract top features from model
        importances = model.feature_importances_
        indices = np.argsort(importances)[::-1]

        print('Feature ranking:')
        for f in range(30):
            print('%d. Feature %d (%f)' % (f + 1, indices[f], importances[indices[f]]))

        # Test model
        y_train_pred = model.predict(train_data)
        y_test_pred = model.predict(test_data)

        # Evaluate model
        print('\nDecision Tree - \nTrain Accuracy: ', round(np.sum(y_train_pred == train_labels) / train_data.shape[0], 4))
        print('Test Accuracy: ', round(np.sum(y_test_pred == test_labels) / test_data.shape[0], 4))
        print('-------------------------------------------')

# %%
# Fetch data
ng_train = fetch_20newsgroups(subset='train')
ng_test = fetch_20newsgroups(subset='test')

# Training and testing data
X_train = ng_train.data
X_test = ng_test.data

# Set of label names for training and testing data
# ng_train.target_names
# ng_test.target_names

# Training and testing labels, where each label is associated with a number corresponding to the index in target_names
# ng_train.target
# ng_test.target

# Training and testing labels
y_train = []
y_test = []

for i in range(len(X_train)):
    y_train.append(ng_train.target_names[ng_train.target[i]])
for i in range(len(X_test)):
    y_test.append(ng_test.target_names[ng_test.target[i]])

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 11314
# 7532
# 11314
# 7532

# %%
# Logistic Regression

# Converting text to vectors
tfidf = TfidfVectorizer()
tfidf.fit(X_train)
vect_X_train = tfidf.transform(X_train)
vect_X_test = tfidf.transform(X_test)

print(vect_X_train.shape)
print(vect_X_test.shape)

model = LogisticRegression(penalty='l2', random_state=42)

model.fit(vect_X_train, y_train)
importances = model.coef_      # Scores of each feature
    
# Store top k features
features = tfidf.get_feature_names()
for i in range(len(importances)):
    print('\nFeatures for label ' + str(i) + ':')
    indices = np.argsort(importances[i])[::-1]

    new_features = []
    for f in range(30):
        new_features.append(features[indices[f]])
    print(new_features)
    print('-------------------------------------------')

# Test model
y_train_pred = model.predict(vect_X_train)
y_test_pred = model.predict(vect_X_test)

# Evaluate model
print('\nLogistic Regression - \nTrain Accuracy: ', round(np.sum(y_train_pred == y_train) / vect_X_train.shape[0], 4))
print('-------------------------------------------')
print('Test Accuracy: ', round(np.sum(y_test_pred == y_test) / vect_X_test.shape[0], 4))
# Out:
# (11314, 130107)
# (7532, 130107)
#
# Features for label 0:
# ['keith', 'atheism', 'atheists', 'caltech', 'islamic', 'islam', 'okcforum', 'mathew', 'god', 'livesey', 'jaeger', 'rushdie', 'is', 'benedikt', 'religion', 'mangoe', 'edu', 'umd', 'sgi', 'osrhe', 'kmr4', 'wingate', 'cobb', 'tek', 'mantis', 'solntze', 'ico', 'bible', 'gregg', 'wpd']
# -------------------------------------------
#
# Features for label 1:
# ['graphics', 'image', '3d', 'polygon', 'tiff', 'images', 'cview', 'points', 'files', 'format', '3do', 'pov', 'animation', 'package', 'vga', 'sphere', 'gif', 'color', 'program', 'vesa', 'algorithm', 'surface', 'file', '42', 'library', 'quicktime', 'code', 'software', '24', 'looking']
# -------------------------------------------
#
# Features for label 2:
# ['windows', 'file', 'ax', 'driver', 'drivers', 'files', 'cica', 'dos', 'mouse', 'win', 'nt', 'risc', 'ini', 'ms', 'win3', 'font', 'fonts', 'printer', 'microsoft', 'access', 'ftp', 'using', 'program', 'card', 'bmp', 'use', 'diamond', 'manager', 'problem', 'deskjet']
# -------------------------------------------
#
# Features for label 3:
# ['drive', 'scsi', 'card', 'pc', 'bus', 'ide', 'gateway', 'controller', 'monitor', '486', 'port', 'vlb', 'bios', 'motherboard', 'disk', 'isa', 'floppy', 'irq', 'monitors', 'eisa', 'help', 'dos', 'ibm', 'board', 'drives', 'thanks', 'cpu', 'memory', 'boot', 'system']
# -------------------------------------------
#
# Features for label 4:
# ['mac', 'apple', 'quadra', 'duo', 'centris', 'powerbook', 'se', 'lc', 'lciii', 'monitor', 'simms', 'iisi', 'modem', 'bmug', 'c650', 'adb', 'drive', 'simm', 'nubus', 'vram', '610', 'upgrade', 'clock', 'macintosh', 'internal', 'macs', 'problem', 'speed', 'ram', 'fpu']
# -------------------------------------------
#
# Features for label 5:
# ['window', 'motif', 'server', 'widget', 'mit', 'xterm', 'x11r5', 'lcs', 'xlib', 'application', 'expo', 'xpert', 'display', 'code', 'x11', 'sun', 'running', 'widgets', 'color', 'r5', 'lib', 'clients', 'imake', 'xdm', 'colormap', 'enterpoop', 'client', 'internet', 'program', 'visual']
# -------------------------------------------
#
# Features for label 6:
# ['sale', 'for', 'shipping', 'offer', 'forsale', 'sell', '00', 'condition', 'price', 'interested', 'asking', 'wanted', 'new', 'call', 'games', 'mail', 'distribution', 'trade', 'includes', 'offers', 'excellent', 'email', 'purdue', 'selling', 'obo', 'hiram', 'cd', 'ohio', 'brand', 'original']
# -------------------------------------------
#
# Features for label 7:
# ['car', 'cars', 'engine', 'oil', 'dealer', 'ford', 'toyota', 'automotive', 'auto', 'callison', 'eliot', 'honda', 'autos', 'com', 'wagon', 'boyle', 'warning', 'my', 'saturn', 'unisql', 'vw', 'driving', 'dumbest', 'centerline', 'road', 'convertible', 'qazi', 'sho', 'nissan', 'integra']
# -------------------------------------------
#
# Features for label 8:
# ['bike', 'dod', 'bikes', 'motorcycle', 'bmw', 'ride', 'riding', 'helmet', 'motorcycles', 'rider', 'dog', 'com', 'my', 'ranck', 'honda', 'ama', 'bnr', 'moa', 'harley', 'sun', 'howland', 'behanna', 'front', 'stafford', 'infante', 'ed', 'yamaha', 'east', 'ducati', 'winona']
# -------------------------------------------
#
# Features for label 9:
# ['baseball', 'he', 'phillies', 'players', 'year', 'cubs', 'runs', 'braves', 'pitching', 'team', 'edu', 'sox', 'game', 'ball', 'alomar', 'mets', 'hit', 'games', 'stadium', 'jewish', 'hitter', 'fan', 'tigers', 'win', 'his', 'last', 'yankees', 'jays', 'nl', 'uniforms']
# -------------------------------------------
#
# Features for label 10:
# ['hockey', 'nhl', 'team', 'game', 'ca', 'play', 'playoff', 'players', 'leafs', 'go', 'season', 'cup', 'espn', 'he', 'pens', 'teams', 'detroit', 'playoffs', 'pittsburgh', 'wings', 'devils', 'rangers', 'ice', 'games', 'penguins', 'flyers', 'toronto', 'montreal', 'coach', 'abc']
# -------------------------------------------
#
# Features for label 11:
# ['clipper', 'key', 'encryption', 'chip', 'nsa', 'pgp', 'keys', 'gtoal', 'security', 'crypto', 'tapped', 'des', 'government', 'cryptography', 'secret', 'escrow', 'code', 'qualcomm', 'eff', 'encrypted', 'netcom', 'com', 'algorithm', 'privacy', 'wiretap', 'na', 'tempest', 'intercon', 'public', 'bontchev']
# -------------------------------------------
#
# Features for label 12:
# ['circuit', 'electronics', 'power', 'radar', 'voltage', 'tv', 'amp', 'ground', 'audio', 'radio', 'detector', 'cooling', 'current', 'line', 'ee', 'use', 'motorola', 'circuits', 'phone', 'wire', '8051', 'output', 'babb', 'design', 'hp', 'low', 'adcom', 'uv', 'receiver', 'scope']
# -------------------------------------------
#
# Features for label 13:
# ['msg', 'doctor', 'pitt', 'disease', 'medical', 'geb', 'banks', 'gordon', 'dyer', 'treatment', 'pain', 'food', 'cancer', 'she', 'health', 'medicine', 'patients', 'photography', 'science', 'foods', 'is', 'of', 'information', 'med', 'diet', 'zisfein', 'syndrome', 'eye', 'yeast', 'symptoms']
# -------------------------------------------
#
# Features for label 14:
# ['space', 'moon', 'nasa', 'orbit', 'launch', 'henry', 'alaska', 'digex', 'pat', 'shuttle', 'sci', 'lunar', 'spacecraft', 'earth', 'access', 'dc', 'prb', 'aurora', 'flight', 'solar', 'rockets', 'ti', 'zoo', 'sky', 'nsmca', 'mccall', 'dietz', 'dseg', 'mars', 'higgins']
# -------------------------------------------
#
# Features for label 15:
# ['god', 'church', 'rutgers', 'christians', 'athos', 'christ', 'christian', 'christianity', 'clh', 'jesus', 'hell', 'bible', 'we', 'of', 'catholic', '1993', 'petch', 'sin', 'apr', 'faith', 'easter', 'geneva', 'resurrection', 'scripture', 'fisher', 'married', 'heaven', 'our', 'sabbath', 'jayne']
# -------------------------------------------
#
# Features for label 16:
# ['gun', 'guns', 'waco', 'fbi', 'firearms', 'weapons', 'atf', 'batf', 'stratus', 'feustel', 'fire', 'nra', 'weapon', 'handgun', 'militia', 'rights', 'government', 'cdt', 'amendment', 'firearm', 'com', 'ranch', 'handheld', 'ifas', 'gnv', 'survivors', 'uic', 'colorado', 'law', 'dividian']
# -------------------------------------------
#
# Features for label 17:
# ['israel', 'israeli', 'turkish', 'jews', 'armenians', 'armenian', 'armenia', 'arab', 'serdar', 'turkey', 'argic', 'mcgill', 'jake', 'of', 'soldiers', 'jewish', 'cosmo', 'cpr', 'angmar', 'fourd', 'holocaust', 'arabs', 'turks', 'adl', 'policy', 'columbia', 'adam', 'were', 'zionism', 'iran']
# -------------------------------------------
#
# Features for label 18:
# ['clinton', 'kaldis', 'cramer', 'tax', 'optilink', 'drugs', 'gay', 'president', 'government', 'br', 'jobs', 'clayton', 'isc', 'state', 'health', 'sexual', 'ipser', 'hallam', 'com', 'drieux', 'to', 'broward', 'trial', 'insurance', 'rutgers', 'romulus', 'ten', 'phil', 'writes', 'deficit']
# -------------------------------------------
#
# Features for label 19:
# ['christian', 'sandvik', 'morality', 'koresh', 'jesus', 'objective', 'god', 'hudson', 'biblical', 'brian', 'buffalo', 'order', 'weiss', 'kent', 'of', 'frank', 'rosicrucian', 'ch981', 'you', 'tyre', 'mormons', 'beast', 'amdahl', 'mitre', 'alicea', 'tony', 'jim', 'joslin', 'thyagi', 'religion']
# -------------------------------------------
#
# Logistic Regression -
# Train Accuracy:  0.9699
# -------------------------------------------
# Test Accuracy:  0.8279

# %%
# Decision Tree

# Converting text to vectors
tfidf = TfidfVectorizer()
tfidf.fit(X_train)
vect_X_train = tfidf.transform(X_train)
vect_X_test = tfidf.transform(X_test)

print(vect_X_train.shape)
print(vect_X_test.shape)

# Train model
model = DecisionTreeClassifier(random_state=42)
for model in [
    DecisionTreeClassifier(random_state=42), 
    DecisionTreeClassifier(random_state=42, max_depth=10), 
    DecisionTreeClassifier(random_state=42, min_samples_leaf=2), 
    DecisionTreeClassifier(random_state=42, min_samples_split=3)
]:

    model.fit(vect_X_train, y_train)

    # Extract top features from model
    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1]

    # Store top k features
    features = tfidf.get_feature_names()
    new_features = []
    print('\nFeatures:')
    for f in range(30):
        new_features.append(features[indices[f]])
    print(new_features)
    print('-------------------------------------------')
    
    # Test model
    y_train_pred = model.predict(vect_X_train)
    y_test_pred = model.predict(vect_X_test)

    # Evaluate model
    print('\nDecision Tree - \nTrain Accuracy: ', round(np.sum(y_train_pred == y_train) / vect_X_train.shape[0], 4))
    print('-------------------------------------------')
    print('Test Accuracy: ', round(np.sum(y_test_pred == y_test) / vect_X_test.shape[0], 4))
# Out:
# (11314, 130107)
# (7532, 130107)
#
# Features:
# ['clipper', 'sale', 'dod', 'windows', 'hockey', 'god', 'car', 'israel', 'space', 'gun', 'baseball', 'turkish', 'bike', 'mac', 'graphics', 'rutgers', 'window', 'geb', 'atheists', 'nhl', 'the', 'encryption', 'motif', 're', 'controller', 'waco', 'team', 'orbit', 'disease', 'clinton']
# -------------------------------------------
#
# Decision Tree -
# Train Accuracy:  0.9999
# -------------------------------------------
# Test Accuracy:  0.5547
#
# Features:
# ['clipper', 'sale', 'dod', 'windows', 'hockey', 'israel', 'car', 'space', 'god', 'gun', 'rutgers', 'article', 'bike', 'motif', 'the', 'guns', 'monitor', 'harvard', 'dan', 'christ', 'graphics', 'delta', 'scsi', 'expo', 'radio', 'server', '___________________the', 'appear', 'romulus', 'ike']
# -------------------------------------------
#
# Decision Tree -
# Train Accuracy:  0.3441
# -------------------------------------------
# Test Accuracy:  0.2998
#
# Features:
# ['clipper', 'sale', 'dod', 'windows', 'hockey', 'car', 'god', 'israel', 'space', 'gun', 'baseball', 'turkish', 'bike', 'mac', 'graphics', 'nhl', 'window', 'geb', 'rutgers', 'atheists', 'the', 'encryption', 'motif', 're', 'waco', 'controller', 'team', 'orbit', 'disease', 'clinton']
# -------------------------------------------
#
# Decision Tree -
# Train Accuracy:  0.931
# -------------------------------------------
# Test Accuracy:  0.5481
#
# Features:
# ['clipper', 'sale', 'dod', 'windows', 'hockey', 'god', 'car', 'israel', 'space', 'gun', 'baseball', 'turkish', 'bike', 'mac', 'graphics', 'rutgers', 'window', 'geb', 'atheists', 'nhl', 'encryption', 'motif', 'the', 're', 'controller', 'apple', 'team', 'waco', 'orbit', 'disease']
# -------------------------------------------
#
# Decision Tree -
# Train Accuracy:  0.9732
# -------------------------------------------
# Test Accuracy:  0.5499
